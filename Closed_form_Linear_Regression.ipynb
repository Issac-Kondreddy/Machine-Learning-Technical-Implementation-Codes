# %%
import numpy as np
import matplotlib.pyplot as plt
class GradientDescentLinearRegression:
    def __init__(self, learning_rate=0.01, iterations=1000):
        self.m =None
        self.b = None
        self.lr = learning_rate
        self.iter = iterations
        self.history = []
    def fit(self, X, y):
        X = np.array(X)
        y = np.array(y)
        n = len(X)
        m = 0
        b = 0
        for _ in range(self.iter):
            y_pred = m*X+b
            error = y - y_pred
            dm = (-2/n)*np.sum(X*error)
            db = (-2/n)*np.sum(error)
            m -= self.lr * dm
            b -= self.lr * db
            loss = np.mean(error**2)
            self.history.append(loss)
        self.m = m
        self.b = b

    def predict(self,X):
        y_pred = []
        for x in X:
            y_pre = self.m * x + self.b
            y_pred.append(y_pre)
        return y_pred

# %%
X = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])
model = GradientDescentLinearRegression()
model.fit(X,y)
print(f"Slope of the model : {model.m}")
print(f"Intercept of the model : {model.b}")
y_pred = model.predict(X)
print("Predictions: ", y_pred)
# Out:
# Slope of the model : 0.6176946148762643
# Intercept of the model : 2.136116825825789
# Predictions:  [2.7538114407020533, 3.3715060555783176, 3.989200670454582, 4.606895285330847, 5.224589900207111]

# %%
plt.plot(range(model.iter), model.history)
plt.xlabel("Iterations")
plt.ylabel("Mean Squared Error")
plt.grid(True)
plt.title("Loss vs Iterations")
plt.show()
